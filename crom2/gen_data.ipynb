# %%
import mysql.connector
import uuid
import random
import datetime
import hashlib
from faker import Faker

# Initialize Faker for generating descriptions
fake = Faker()

# Database connection configuration
DB_CONFIG = {
    'host': 'localhost',
    'user': 'root',  # Replace with your MySQL username
    'password': 'rootpassword',  # Replace with your MySQL password
    'database': 'lbdr_db'
}

# Configuration
SQL_FILE_PATH = './Database/test_data.sql'
DB_NAME = 'lbdr_db'

# Data pools
first_names = ["Alice", "Bob", "Charlie", "David", "Emma", "Fiona", "George", "Hannah", "Ian", "Julia",
               "Kevin", "Laura", "Michael", "Nina", "Oliver", "Paul", "Quinn", "Rachel", "Steven", "Tina"]
last_names = ["Martin", "Dupont", "Schneider", "Rossi", "Smith", "Nguyen", "Kumar", "Lopez", "Brown", "Müller"]
sexes = ["M", "F", "Other"]
board_games = ["Fallout", "King of New York", "King of Tokyo", "Zombicide", 
               "Darkest Dungeon", "Root", "Pour la reine", "Gloomhaven", "Pandemic"]
jdr_games = ["1D8", "7ème Mer", "Advanced Bernard&Jean", "Adventure Party", "Agone", 
             "Alien", "An 1000", "Anima", "Appel de Cthulhu", "ARIA"]

# %%
import re

# Read plateau games file
with open('./jeux de plateau.txt', 'r', encoding='utf-8') as f:
    plateau_html = f.read()

# Read JDR games file
with open('./JDR.txt', 'r', encoding='utf-8') as f:
    jdr_html = f.read()

# Regex to extract option texts
board_games = re.findall(r'<option[^>]*>([^<]+)</option>', plateau_html)
jdr_games = re.findall(r'<option[^>]*>([^<]+)</option>', jdr_html)

# Filter out placeholders
board_games = [g.strip() for g in board_games if g.strip() and not g.strip().lower().startswith('jeu de plateau')]
# Remove duplicates
board_games = list(dict.fromkeys(board_games))

jdr_games = [g.strip() for g in jdr_games if g.strip() and not g.strip().startswith('--')]
# Remove duplicates and sort a bit
jdr_games = list(dict.fromkeys(jdr_games))

# Additional plateau games
additional_plateau = ["Darkest Dungeon", "Root", "Pour la reine", "Gloomhaven", "Pandemic"]
for g in additional_plateau:
    if g not in board_games:
        board_games.append(g)
        
board_games = list(set(board_games))
jdr_games = list(set(jdr_games))

# %%
def random_date(start_year=1970, end_year=2002):
    start = datetime.date(start_year, 1, 1)
    end = datetime.date(end_year, 12, 31)
    return start + datetime.timedelta(days=random.randint(0, (end - start).days))

def random_registration_date():
    start = datetime.date(2020, 1, 1)
    end = datetime.date.today()
    return start + datetime.timedelta(days=random.randint(0, (end - start).days))

def make_user(fn, ln, user_type, pwd_plain, used_usernames, used_emails):
    uid = str(uuid.uuid4())
    bd = random_date().isoformat()
    sex = random.choice(sexes)
    discord = f"{fn.lower()}#{random.randint(1000,9999)}"
    pseudo = fn.lower() + str(random.randint(1,9999))
    
    # Generate unique username
    attempt = 0
    while True:
        suffix = str(random.randint(1, 9999)) if attempt > 0 else str(random.randint(1,99))
        username = f"{fn.lower()}.{ln.lower()}{suffix}"
        email = f"{username}@example.com"
        if username not in used_usernames and email not in used_emails:
            used_usernames.add(username)
            used_emails.add(email)
            break
        attempt += 1
    
    salt = uuid.uuid4().hex[:8]
    pwd_hash = hashlib.sha256((salt + pwd_plain).encode()).hexdigest()
    reg_date = random_registration_date().isoformat() if user_type != "NON_REGISTERED" else None
    return {
        'id': uid,
        'first_name': fn,
        'last_name': ln,
        'birth_date': bd,
        'sex': sex,
        'discord_id': discord,
        'pseudonym': pseudo,
        'email': email,
        'username': username,
        'password_hash': pwd_hash,
        'password_salt': salt,
        'user_type': user_type,
        'registration_date': reg_date,
        'old_user': False,
        'first_connection': False
    }

def generate_description(game_name):
    return fake.paragraph(nb_sentences=3, variable_nb_sentences=True).replace("'", "''")

def generate_short_description(game_name, game_type):
    return f"{game_type} de {game_name}".replace("'", "''")

def get_first_sunday(month, year=2025):
    d = datetime.date(year, month, 1)
    while d.weekday() != 6:  # Sunday
        d += datetime.timedelta(days=1)
    return d

# %%
# Connect to database
try:
    conn = mysql.connector.connect(**DB_CONFIG)
    cursor = conn.cursor()
    print("Connected to database")
except mysql.connector.Error as err:
    print(f"Error connecting to database: {err}")
    exit(1)
# Out:
# Connected to database

# %%
# Generate users
users = []
used_usernames = set()
used_emails = set()
for i in range(50):
    fn = first_names[i % len(first_names)]
    ln = last_names[i % len(last_names)]
    users.append(make_user(fn, ln, "REGISTERED", fn.lower(), used_usernames, used_emails))
users.append(make_user("Admin", "User", "ADMINISTRATOR", "admin", used_usernames, used_emails))

# Insert users
user_insert = """
INSERT INTO users (id, first_name, last_name, birth_date, sex, discord_id, pseudonym, email, username, 
                 password_hash, password_salt, user_type, registration_date, old_user, first_connection)
VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
"""
for user in users:
    cursor.execute(user_insert, (
        user['id'], user['first_name'], user['last_name'], user['birth_date'], user['sex'],
        user['discord_id'], user['pseudonym'], user['email'], user['username'],
        user['password_hash'], user['password_salt'], user['user_type'],
        user['registration_date'], user['old_user'], user['first_connection']
    ))
    print(user)
# Out:
# {'id': 'f6b2bfe8-41a0-43d4-92e6-761f671b0fe8', 'first_name': 'Alice', 'last_name': 'Martin', 'birth_date': '1976-07-27', 'sex': 'F', 'discord_id': 'alice#6044', 'pseudonym': 'alice9036', 'email': 'alice.martin45@example.com', 'username': 'alice.martin45', 'password_hash': 'a368e29d6fe80901ffe4e3c0be835a830398fe1eef8b7f7432bff2af16e18a10', 'password_salt': '8662d046', 'user_type': 'REGISTERED', 'registration_date': '2020-06-29', 'old_user': False, 'first_connection': False}
# {'id': 'e7a1efbc-ba79-4355-8010-96be491c8fe6', 'first_name': 'Bob', 'last_name': 'Dupont', 'birth_date': '2002-01-09', 'sex': 'F', 'discord_id': 'bob#1942', 'pseudonym': 'bob3660', 'email': 'bob.dupont72@example.com', 'username': 'bob.dupont72', 'password_hash': 'a25067eefe519c4403bbd97c8d22b2e37af58f4f47ea0f80719bf1f7a5573722', 'password_salt': '6384a39b', 'user_type': 'REGISTERED', 'registration_date': '2020-11-03', 'old_user': False, 'first_connection': False}
# {'id': '80fb82e6-1851-4500-a59a-0713592a0138', 'first_name': 'Charlie', 'last_name': 'Schneider', 'birth_date': '1976-03-16', 'sex': 'F', 'discord_id': 'charlie#5314', 'pseudonym': 'charlie6154', 'email': 'charlie.schneider15@example.com', 'username': 'charlie.schneider15', 'password_hash': '71a52f4d042b7d6c66daed1f574187b30d8fd2a2206ee5768d5c482d91bbac60', 'password_salt': '98a16d35', 'user_type': 'REGISTERED', 'registration_date': '2021-02-07', 'old_user': False, 'first_connection': False}
# {'id': 'b0f786bc-4a9f-40d1-ba22-b063af651454', 'first_name': 'David', 'last_name': 'Rossi', 'birth_date': '1971-05-09', 'sex': 'Other', 'discord_id': 'david#5886', 'pseudonym': 'david9244', 'email': 'david.rossi54@example.com', 'username': 'david.rossi54', 'password_hash': '1d55652886e8114b94e30c6edc4a36032ba9e06693e451d85193e27b67e0a2e1', 'password_salt': '3f6529dd', 'user_type': 'REGISTERED', 'registration_date': '2021-08-21', 'old_user': False, 'first_connection': False}
# {'id': 'b91376ab-690d-4c3d-a809-325be489eb5c', 'first_name': 'Emma', 'last_name': 'Smith', 'birth_date': '1986-10-29', 'sex': 'Other', 'discord_id': 'emma#2514', 'pseudonym': 'emma4879', 'email': 'emma.smith76@example.com', 'username': 'emma.smith76', 'password_hash': '0ebfe289be75b289fae737879ebb5534e51359096920dd2bf9a069f31daec50a', 'password_salt': 'e16f72f7', 'user_type': 'REGISTERED', 'registration_date': '2021-12-03', 'old_user': False, 'first_connection': False}
# {'id': '9db3b89e-4fbc-4b4e-a62f-e8d270820172', 'first_name': 'Fiona', 'last_name': 'Nguyen', 'birth_date': '1984-02-13', 'sex': 'Other', 'discord_id': 'fiona#8889', 'pseudonym': 'fiona1633', 'email': 'fiona.nguyen37@example.com', 'username': 'fiona.nguyen37', 'password_hash': '4ba94361c7b0f2989fdcce8b2a4b90223290d4a5adeed1622a1333f1a0134547', 'password_salt': '1392e2ca', 'user_type': 'REGISTERED', 'registration_date': '2020-06-09', 'old_user': False, 'first_connection': False}
# {'id': '768eb2f5-1056-4ac6-9f99-6f2721363b87', 'first_name': 'George', 'last_name': 'Kumar', 'birth_date': '1988-08-16', 'sex': 'M', 'discord_id': 'george#5440', 'pseudonym': 'george2741', 'email': 'george.kumar59@example.com', 'username': 'george.kumar59', 'password_hash': '161d2e7415d8f9b023d950718dc4c2c6f2ddfa0420c9f68c594e774f749aab22', 'password_salt': '9fbe49a2', 'user_type': 'REGISTERED', 'registration_date': '2023-11-18', 'old_user': False, 'first_connection': False}
# {'id': '0cd34732-c6ce-4985-a889-77a5b1800664', 'first_name': 'Hannah', 'last_name': 'Lopez', 'birth_date': '2002-04-28', 'sex': 'M', 'discord_id': 'hannah#1732', 'pseudonym': 'hannah714', 'email': 'hannah.lopez43@example.com', 'username': 'hannah.lopez43', 'password_hash': '4ef5337b48999904e1948cd2d5b3cbda78e8c66e6951c73f02c785401b182e76', 'password_salt': '11e1c2f7', 'user_type': 'REGISTERED', 'registration_date': '2022-05-31', 'old_user': False, 'first_connection': False}
# {'id': '7ede8ddf-0e93-4391-a6fe-3d7bf25a4ce0', 'first_name': 'Ian', 'last_name': 'Brown', 'birth_date': '1993-10-28', 'sex': 'Other', 'discord_id': 'ian#2134', 'pseudonym': 'ian2234', 'email': 'ian.brown22@example.com', 'username': 'ian.brown22', 'password_hash': 'b7a47954ff3cae331c31f0bfa37f97e0aeea1bfa977fcc543a9a07bd158d44f9', 'password_salt': '34c5a477', 'user_type': 'REGISTERED', 'registration_date': '2023-07-07', 'old_user': False, 'first_connection': False}
# {'id': '2653e389-03e1-4bbf-ad0b-efad62f8a8bf', 'first_name': 'Julia', 'last_name': 'Müller', 'birth_date': '1995-08-26', 'sex': 'F', 'discord_id': 'julia#8560', 'pseudonym': 'julia2090', 'email': 'julia.müller39@example.com', 'username': 'julia.müller39', 'password_hash': '9a99f5e701f74e21bf6c79ed360776a001605857e0d6ffc4330b607b92a38f13', 'password_salt': '7ca27beb', 'user_type': 'REGISTERED', 'registration_date': '2020-02-07', 'old_user': False, 'first_connection': False}
# {'id': '45eef62a-e315-4c2f-99cd-e5f673ba589b', 'first_name': 'Kevin', 'last_name': 'Martin', 'birth_date': '1982-10-19', 'sex': 'Other', 'discord_id': 'kevin#6552', 'pseudonym': 'kevin1417', 'email': 'kevin.martin97@example.com', 'username': 'kevin.martin97', 'password_hash': 'e14f6dff858a46262df7dfa8fa7993622692a99ca66d0b221b74933aa06ddc36', 'password_salt': '597987c8', 'user_type': 'REGISTERED', 'registration_date': '2023-04-12', 'old_user': False, 'first_connection': False}
# {'id': 'b57b0d96-dd83-4fb6-815f-afafed31ce72', 'first_name': 'Laura', 'last_name': 'Dupont', 'birth_date': '1982-08-20', 'sex': 'Other', 'discord_id': 'laura#3661', 'pseudonym': 'laura3330', 'email': 'laura.dupont25@example.com', 'username': 'laura.dupont25', 'password_hash': 'f131cac474ffb12c261157c4057be899d61855d7064759bbcb70640c6765cb9b', 'password_salt': '6aa126a6', 'user_type': 'REGISTERED', 'registration_date': '2022-07-14', 'old_user': False, 'first_connection': False}
# {'id': 'e18d6423-c4a1-40ca-86df-d13fd2e57eba', 'first_name': 'Michael', 'last_name': 'Schneider', 'birth_date': '1995-05-07', 'sex': 'Other', 'discord_id': 'michael#7156', 'pseudonym': 'michael1156', 'email': 'michael.schneider57@example.com', 'username': 'michael.schneider57', 'password_hash': 'e93c95e971cec3467c851c628acb37bdd13d766860eb28d7c262d097b11cba8a', 'password_salt': '894b6d73', 'user_type': 'REGISTERED', 'registration_date': '2021-01-29', 'old_user': False, 'first_connection': False}
# {'id': '85fd6d99-1fe8-44a3-8e05-ba2b42a4ec10', 'first_name': 'Nina', 'last_name': 'Rossi', 'birth_date': '1980-09-07', 'sex': 'F', 'discord_id': 'nina#3977', 'pseudonym': 'nina6182', 'email': 'nina.rossi41@example.com', 'username': 'nina.rossi41', 'password_hash': '4c314776fc570faa401a54d6cbd41c4cb1a0f4304703f648db29e29f936d539d', 'password_salt': '252d0ed5', 'user_type': 'REGISTERED', 'registration_date': '2025-03-01', 'old_user': False, 'first_connection': False}
# {'id': 'b16c6388-3e36-407d-bd5e-a879fb625852', 'first_name': 'Oliver', 'last_name': 'Smith', 'birth_date': '1982-10-30', 'sex': 'F', 'discord_id': 'oliver#3775', 'pseudonym': 'oliver8988', 'email': 'oliver.smith37@example.com', 'username': 'oliver.smith37', 'password_hash': '5de542b97a740b38cac6f12023f8da767acbf7202ebda19c8464dd50b82c180f', 'password_salt': '7c6a8dd0', 'user_type': 'REGISTERED', 'registration_date': '2022-11-21', 'old_user': False, 'first_connection': False}
# {'id': 'ca8d00f1-c21d-4328-bb67-7398dda7056c', 'first_name': 'Paul', 'last_name': 'Nguyen', 'birth_date': '1973-07-30', 'sex': 'F', 'discord_id': 'paul#1644', 'pseudonym': 'paul9062', 'email': 'paul.nguyen88@example.com', 'username': 'paul.nguyen88', 'password_hash': 'c0465608424cdc971f56141ca9018b2dc65e4d159ffb68eb38462bef2fb2bf09', 'password_salt': 'ea917e34', 'user_type': 'REGISTERED', 'registration_date': '2024-06-01', 'old_user': False, 'first_connection': False}
# {'id': 'b0b139d8-6f4a-4999-850a-1af1ccedc6d8', 'first_name': 'Quinn', 'last_name': 'Kumar', 'birth_date': '1970-06-24', 'sex': 'M', 'discord_id': 'quinn#4080', 'pseudonym': 'quinn6914', 'email': 'quinn.kumar10@example.com', 'username': 'quinn.kumar10', 'password_hash': '931b0cdbce04c88653d3f0ca52d1f73f2912830c9825e16368b802055981e70c', 'password_salt': '2f96d231', 'user_type': 'REGISTERED', 'registration_date': '2023-03-24', 'old_user': False, 'first_connection': False}
# {'id': '4d330505-13cd-4b29-8e1f-5c1bb8bf1f59', 'first_name': 'Rachel', 'last_name': 'Lopez', 'birth_date': '1975-09-14', 'sex': 'F', 'discord_id': 'rachel#1084', 'pseudonym': 'rachel909', 'email': 'rachel.lopez65@example.com', 'username': 'rachel.lopez65', 'password_hash': '367d00d016a125f05e969c4e03f7702ca671c33e6623435a2d69448daed177dd', 'password_salt': '53215b89', 'user_type': 'REGISTERED', 'registration_date': '2022-07-25', 'old_user': False, 'first_connection': False}
# {'id': '36f39f42-8899-4205-92aa-6fabc369ae80', 'first_name': 'Steven', 'last_name': 'Brown', 'birth_date': '1979-01-18', 'sex': 'F', 'discord_id': 'steven#2939', 'pseudonym': 'steven6729', 'email': 'steven.brown10@example.com', 'username': 'steven.brown10', 'password_hash': 'b0779dc13dee34045747f60e86cf4013f56f412f099cc43d5e407c6007aeffcd', 'password_salt': '1d97c058', 'user_type': 'REGISTERED', 'registration_date': '2021-01-05', 'old_user': False, 'first_connection': False}
# {'id': '1e744d66-e1d7-4695-aaba-721afde008f4', 'first_name': 'Tina', 'last_name': 'Müller', 'birth_date': '1991-06-21', 'sex': 'Other', 'discord_id': 'tina#1167', 'pseudonym': 'tina7558', 'email': 'tina.müller84@example.com', 'username': 'tina.müller84', 'password_hash': '28d2525920600b23f3e691e18fc72e25d8355d5847bef627d951bf0e5e051d26', 'password_salt': '1c670709', 'user_type': 'REGISTERED', 'registration_date': '2023-08-05', 'old_user': False, 'first_connection': False}
# {'id': '2dab7bae-c880-4150-ad30-64590d2c6340', 'first_name': 'Alice', 'last_name': 'Martin', 'birth_date': '1994-04-18', 'sex': 'M', 'discord_id': 'alice#4557', 'pseudonym': 'alice1875', 'email': 'alice.martin8@example.com', 'username': 'alice.martin8', 'password_hash': '975266661bc02774383e2016c482f3c30db3fcbeaea84b479a08c772ad7cacd5', 'password_salt': 'b110cb9a', 'user_type': 'REGISTERED', 'registration_date': '2023-08-26', 'old_user': False, 'first_connection': False}
# {'id': 'e0082ea5-a627-4758-a734-9c1c3da094f6', 'first_name': 'Bob', 'last_name': 'Dupont', 'birth_date': '2002-03-23', 'sex': 'M', 'discord_id': 'bob#6821', 'pseudonym': 'bob9554', 'email': 'bob.dupont39@example.com', 'username': 'bob.dupont39', 'password_hash': 'afcff5edcdf7ef19a4d9f533650e1f2d3dee179f668280dce3a218ca09129fc7', 'password_salt': 'c5c49627', 'user_type': 'REGISTERED', 'registration_date': '2020-03-31', 'old_user': False, 'first_connection': False}
# {'id': '3a98249c-36b3-4d84-b18b-00d6d136d3a9', 'first_name': 'Charlie', 'last_name': 'Schneider', 'birth_date': '1980-11-14', 'sex': 'F', 'discord_id': 'charlie#2695', 'pseudonym': 'charlie6366', 'email': 'charlie.schneider34@example.com', 'username': 'charlie.schneider34', 'password_hash': '0acbec64922e7ef282d2b4eb9c4fae2ae08e06960ab2dbfd4c9baae8fe7f3dab', 'password_salt': '859c22c4', 'user_type': 'REGISTERED', 'registration_date': '2020-06-17', 'old_user': False, 'first_connection': False}
# {'id': '0ecb45b6-e0dd-4b64-8056-4c35f13f399b', 'first_name': 'David', 'last_name': 'Rossi', 'birth_date': '1995-12-13', 'sex': 'M', 'discord_id': 'david#8834', 'pseudonym': 'david8204', 'email': 'david.rossi23@example.com', 'username': 'david.rossi23', 'password_hash': 'f7bd2cbfa5db319473229edc5b13f439cef71bb43db44e1b368bae187c48d78c', 'password_salt': 'a2281105', 'user_type': 'REGISTERED', 'registration_date': '2025-03-12', 'old_user': False, 'first_connection': False}
# {'id': '3cc85710-45d3-4d18-a5fb-bd3cf726cd6d', 'first_name': 'Emma', 'last_name': 'Smith', 'birth_date': '2002-01-26', 'sex': 'Other', 'discord_id': 'emma#6780', 'pseudonym': 'emma3245', 'email': 'emma.smith54@example.com', 'username': 'emma.smith54', 'password_hash': '1def3b5932ad1be27ed5906773d9e8010df48f0624d1edca482a157800e122bc', 'password_salt': 'f9454019', 'user_type': 'REGISTERED', 'registration_date': '2021-08-22', 'old_user': False, 'first_connection': False}
# {'id': '86bd3f2e-d004-4c45-8391-a20f2bbaf008', 'first_name': 'Fiona', 'last_name': 'Nguyen', 'birth_date': '1986-09-27', 'sex': 'M', 'discord_id': 'fiona#8689', 'pseudonym': 'fiona8725', 'email': 'fiona.nguyen42@example.com', 'username': 'fiona.nguyen42', 'password_hash': 'a747479c9987bd6f29c86ea991805b0bcc7ab046e332abb313ccc40cfc3e4dde', 'password_salt': '97beaa7b', 'user_type': 'REGISTERED', 'registration_date': '2020-04-12', 'old_user': False, 'first_connection': False}
# {'id': '51cd76c7-b40e-47c3-9c87-43bb9a8ecf68', 'first_name': 'George', 'last_name': 'Kumar', 'birth_date': '1987-05-14', 'sex': 'M', 'discord_id': 'george#1600', 'pseudonym': 'george1972', 'email': 'george.kumar75@example.com', 'username': 'george.kumar75', 'password_hash': '0dbd5ba40add9cec0c1ea4f142dcd4b0af12055902500f02964f4dec88a3f400', 'password_salt': 'f39f37fe', 'user_type': 'REGISTERED', 'registration_date': '2024-01-11', 'old_user': False, 'first_connection': False}
# {'id': 'f3430e18-5d9a-4666-91c2-f69f5a01dde3', 'first_name': 'Hannah', 'last_name': 'Lopez', 'birth_date': '1973-08-17', 'sex': 'Other', 'discord_id': 'hannah#3631', 'pseudonym': 'hannah1298', 'email': 'hannah.lopez69@example.com', 'username': 'hannah.lopez69', 'password_hash': 'e6b532dd6b0c7999ff11b84b50d0a1d000dc01f9bac6f34cc5f64e128f9c1e48', 'password_salt': '9cb2ba66', 'user_type': 'REGISTERED', 'registration_date': '2024-03-05', 'old_user': False, 'first_connection': False}
# {'id': 'c8992fcb-36bc-4017-a754-a2021980d26f', 'first_name': 'Ian', 'last_name': 'Brown', 'birth_date': '1973-08-04', 'sex': 'M', 'discord_id': 'ian#6863', 'pseudonym': 'ian6775', 'email': 'ian.brown26@example.com', 'username': 'ian.brown26', 'password_hash': '4d379f2c2c3f324d7e4de6737302ff117b0192ead8af087e2fd3aeed7228289e', 'password_salt': '1724a3ea', 'user_type': 'REGISTERED', 'registration_date': '2022-04-21', 'old_user': False, 'first_connection': False}
# {'id': '558995ff-824f-454d-84cd-c456d9a2d400', 'first_name': 'Julia', 'last_name': 'Müller', 'birth_date': '1998-06-12', 'sex': 'F', 'discord_id': 'julia#8871', 'pseudonym': 'julia2881', 'email': 'julia.müller55@example.com', 'username': 'julia.müller55', 'password_hash': '2ee4ed8bfbe808b7851af5b38d4fdb8dd5001f99b1f28c953d0a7eb8f976609c', 'password_salt': 'c6666f01', 'user_type': 'REGISTERED', 'registration_date': '2022-09-12', 'old_user': False, 'first_connection': False}
# {'id': '88ced29f-1036-4e3f-86db-ccf7a179cc0a', 'first_name': 'Kevin', 'last_name': 'Martin', 'birth_date': '1989-06-14', 'sex': 'F', 'discord_id': 'kevin#6424', 'pseudonym': 'kevin6169', 'email': 'kevin.martin70@example.com', 'username': 'kevin.martin70', 'password_hash': 'c7633145a196b817079b951f8caa6740f057fb78705ed2159f701f84add51300', 'password_salt': '8e73e62c', 'user_type': 'REGISTERED', 'registration_date': '2022-03-27', 'old_user': False, 'first_connection': False}
# {'id': 'f103f1a0-2de5-4423-98bb-4d211708d27c', 'first_name': 'Laura', 'last_name': 'Dupont', 'birth_date': '1973-04-03', 'sex': 'Other', 'discord_id': 'laura#7198', 'pseudonym': 'laura732', 'email': 'laura.dupont35@example.com', 'username': 'laura.dupont35', 'password_hash': '95ff2bcfa46c77b9bfecb640b56ed974da41d40ce27ac5cc72ce2fe101564bea', 'password_salt': '9da0831b', 'user_type': 'REGISTERED', 'registration_date': '2025-03-23', 'old_user': False, 'first_connection': False}
# {'id': 'bb5c0f49-d817-4b3d-8c94-51d3d941ea89', 'first_name': 'Michael', 'last_name': 'Schneider', 'birth_date': '1977-03-04', 'sex': 'F', 'discord_id': 'michael#6565', 'pseudonym': 'michael7175', 'email': 'michael.schneider9@example.com', 'username': 'michael.schneider9', 'password_hash': '961829dab28773d8542afa55ac8e2ffedb3be191eb040dce5dab146d703e3c24', 'password_salt': '55a65b48', 'user_type': 'REGISTERED', 'registration_date': '2021-01-21', 'old_user': False, 'first_connection': False}
# {'id': 'e9c457f0-c4b9-447e-b724-14248b6d110c', 'first_name': 'Nina', 'last_name': 'Rossi', 'birth_date': '2002-06-02', 'sex': 'Other', 'discord_id': 'nina#8345', 'pseudonym': 'nina9266', 'email': 'nina.rossi70@example.com', 'username': 'nina.rossi70', 'password_hash': '9d0b91749e07c598e4422f9803aa333322f954a3610d6092f065210d94dacde1', 'password_salt': 'f8c4508f', 'user_type': 'REGISTERED', 'registration_date': '2025-04-21', 'old_user': False, 'first_connection': False}
# {'id': '7e57d30a-e30d-4e06-99ff-3dfa6ae7e796', 'first_name': 'Oliver', 'last_name': 'Smith', 'birth_date': '1990-11-05', 'sex': 'F', 'discord_id': 'oliver#6900', 'pseudonym': 'oliver9620', 'email': 'oliver.smith87@example.com', 'username': 'oliver.smith87', 'password_hash': 'de246fa1635b433d4075672306e583484f3ab446ce81642e61429ec5c73c9a6e', 'password_salt': '6937d8ae', 'user_type': 'REGISTERED', 'registration_date': '2020-11-01', 'old_user': False, 'first_connection': False}
# {'id': '29335aa9-e1aa-48c2-8a8f-1e3a7d2f2bbf', 'first_name': 'Paul', 'last_name': 'Nguyen', 'birth_date': '1993-08-27', 'sex': 'M', 'discord_id': 'paul#8528', 'pseudonym': 'paul8115', 'email': 'paul.nguyen27@example.com', 'username': 'paul.nguyen27', 'password_hash': '1100f43bdcaa671ca675368f333b1f2842ba707afc4527a82877b900fa921998', 'password_salt': '5f17f6e8', 'user_type': 'REGISTERED', 'registration_date': '2024-06-02', 'old_user': False, 'first_connection': False}
# {'id': 'b4680dec-769e-40b4-9bf2-9cdbfccad632', 'first_name': 'Quinn', 'last_name': 'Kumar', 'birth_date': '1973-09-07', 'sex': 'F', 'discord_id': 'quinn#4970', 'pseudonym': 'quinn3548', 'email': 'quinn.kumar96@example.com', 'username': 'quinn.kumar96', 'password_hash': '7c10fb7b716b283c3291d0fa42b8ac7e4bbc1eef74a0c91c187fb3d70f66ad87', 'password_salt': '76fb842f', 'user_type': 'REGISTERED', 'registration_date': '2022-07-25', 'old_user': False, 'first_connection': False}
# {'id': '7dc219a7-3537-4ecc-b756-6ba3cfec92f0', 'first_name': 'Rachel', 'last_name': 'Lopez', 'birth_date': '1980-09-07', 'sex': 'M', 'discord_id': 'rachel#4412', 'pseudonym': 'rachel1019', 'email': 'rachel.lopez34@example.com', 'username': 'rachel.lopez34', 'password_hash': '3fcc4d76c188f70510bb7875becaa3a9757b07e97384a47ecee18ab28c1f3775', 'password_salt': '93eba782', 'user_type': 'REGISTERED', 'registration_date': '2022-05-13', 'old_user': False, 'first_connection': False}
# {'id': 'be707f58-be06-40c5-b05e-a96f13111c50', 'first_name': 'Steven', 'last_name': 'Brown', 'birth_date': '1980-12-04', 'sex': 'Other', 'discord_id': 'steven#3391', 'pseudonym': 'steven1814', 'email': 'steven.brown50@example.com', 'username': 'steven.brown50', 'password_hash': 'b0ec3f47ef5dd789aaf71f014eb01b5d30947debfa039d60351f2ee471a9d087', 'password_salt': '86d8fe2d', 'user_type': 'REGISTERED', 'registration_date': '2020-01-23', 'old_user': False, 'first_connection': False}
# {'id': '0cccc1bc-a629-46d1-a4dd-2144d3310393', 'first_name': 'Tina', 'last_name': 'Müller', 'birth_date': '1971-10-17', 'sex': 'F', 'discord_id': 'tina#3566', 'pseudonym': 'tina6908', 'email': 'tina.müller10@example.com', 'username': 'tina.müller10', 'password_hash': 'ae3c9b7b64ca2f74f119e67b5ee9dc78bd9bd8b5ee078b04dea0d386ae2e3080', 'password_salt': 'a211a707', 'user_type': 'REGISTERED', 'registration_date': '2020-10-11', 'old_user': False, 'first_connection': False}
# {'id': 'a8cb82c5-4f2f-4ce4-95af-3e10f6e77470', 'first_name': 'Alice', 'last_name': 'Martin', 'birth_date': '2002-08-12', 'sex': 'Other', 'discord_id': 'alice#8281', 'pseudonym': 'alice4696', 'email': 'alice.martin26@example.com', 'username': 'alice.martin26', 'password_hash': 'e1c517a1b6113f1e784c1d5c03efa744a17117edf47f0aa4b03f13f9ed2ff1de', 'password_salt': 'c12278dd', 'user_type': 'REGISTERED', 'registration_date': '2023-10-28', 'old_user': False, 'first_connection': False}
# {'id': 'b3b128c0-6ac4-4a47-976b-fd53d77d18ac', 'first_name': 'Bob', 'last_name': 'Dupont', 'birth_date': '1977-12-12', 'sex': 'F', 'discord_id': 'bob#1786', 'pseudonym': 'bob9594', 'email': 'bob.dupont16@example.com', 'username': 'bob.dupont16', 'password_hash': '11502ec2679fa20ba1d8a5dace8731a5daca678bf8d19848f691dec1ed1c7be6', 'password_salt': '2f3b9470', 'user_type': 'REGISTERED', 'registration_date': '2023-06-20', 'old_user': False, 'first_connection': False}
# {'id': '7c7e1e47-e59f-46da-8c25-475b2ea6bcf1', 'first_name': 'Charlie', 'last_name': 'Schneider', 'birth_date': '1989-08-31', 'sex': 'F', 'discord_id': 'charlie#7720', 'pseudonym': 'charlie8263', 'email': 'charlie.schneider21@example.com', 'username': 'charlie.schneider21', 'password_hash': 'be505beb0b3001aa8a8a101fb7ad3e6b4b5f3a7d139c08100bb5f86e1f596287', 'password_salt': '46ea5f4a', 'user_type': 'REGISTERED', 'registration_date': '2023-02-25', 'old_user': False, 'first_connection': False}
# {'id': 'e125f563-40e3-4b5d-a0a2-becea31e6a86', 'first_name': 'David', 'last_name': 'Rossi', 'birth_date': '1975-04-03', 'sex': 'M', 'discord_id': 'david#2752', 'pseudonym': 'david8209', 'email': 'david.rossi91@example.com', 'username': 'david.rossi91', 'password_hash': '1af6b6d4083db84fb95583ef2c1be188e09461e1f3976ef64736005840fa0751', 'password_salt': 'eafaa11f', 'user_type': 'REGISTERED', 'registration_date': '2021-07-05', 'old_user': False, 'first_connection': False}
# {'id': '0be46c7a-190d-4adb-ac46-3038dadae50d', 'first_name': 'Emma', 'last_name': 'Smith', 'birth_date': '1987-08-11', 'sex': 'M', 'discord_id': 'emma#1316', 'pseudonym': 'emma85', 'email': 'emma.smith38@example.com', 'username': 'emma.smith38', 'password_hash': '067065db5d6d029c7847e99c7f8528e023529b7ad42d74fdb01ab6e5b4402b95', 'password_salt': 'ecc35118', 'user_type': 'REGISTERED', 'registration_date': '2024-06-17', 'old_user': False, 'first_connection': False}
# {'id': '9308142f-9459-41cf-ad2d-c86f4013c6e7', 'first_name': 'Fiona', 'last_name': 'Nguyen', 'birth_date': '1984-09-04', 'sex': 'F', 'discord_id': 'fiona#4518', 'pseudonym': 'fiona5339', 'email': 'fiona.nguyen44@example.com', 'username': 'fiona.nguyen44', 'password_hash': 'd7a3d7af0f19af0c3a915db3b230dda2065bdc156e09f144a33fb526903a3a12', 'password_salt': 'c54e4a24', 'user_type': 'REGISTERED', 'registration_date': '2023-04-24', 'old_user': False, 'first_connection': False}
# {'id': 'd0065b31-a563-4769-af03-26c90b762c0f', 'first_name': 'George', 'last_name': 'Kumar', 'birth_date': '2001-10-08', 'sex': 'Other', 'discord_id': 'george#1421', 'pseudonym': 'george9484', 'email': 'george.kumar90@example.com', 'username': 'george.kumar90', 'password_hash': 'c2146c39c48519884d96d2ff0b4a50f1cfa0d925d861ac5011677ec45d7cfea8', 'password_salt': '685006d6', 'user_type': 'REGISTERED', 'registration_date': '2020-11-03', 'old_user': False, 'first_connection': False}
# {'id': '9a5ad70b-8195-4117-9662-e64986e3b16e', 'first_name': 'Hannah', 'last_name': 'Lopez', 'birth_date': '1992-03-29', 'sex': 'Other', 'discord_id': 'hannah#5420', 'pseudonym': 'hannah872', 'email': 'hannah.lopez20@example.com', 'username': 'hannah.lopez20', 'password_hash': '60417cc677fee0a6594b97b59442412a534d4d80d18cc8db40da06cdc83b7223', 'password_salt': 'f4f74a1c', 'user_type': 'REGISTERED', 'registration_date': '2020-10-31', 'old_user': False, 'first_connection': False}
# {'id': 'f0feee77-d0fd-4cbf-bbbb-1aa50036aa4d', 'first_name': 'Ian', 'last_name': 'Brown', 'birth_date': '1993-01-21', 'sex': 'M', 'discord_id': 'ian#5184', 'pseudonym': 'ian7596', 'email': 'ian.brown70@example.com', 'username': 'ian.brown70', 'password_hash': '86be9b35370786d326bf33ae071405b181d3fb3bbab7736d006c2056ed6e140b', 'password_salt': '384d7d63', 'user_type': 'REGISTERED', 'registration_date': '2021-03-07', 'old_user': False, 'first_connection': False}
# {'id': '8c2d322d-3234-4a07-8a89-2d30d1c6694e', 'first_name': 'Julia', 'last_name': 'Müller', 'birth_date': '1979-08-14', 'sex': 'M', 'discord_id': 'julia#7765', 'pseudonym': 'julia1290', 'email': 'julia.müller1@example.com', 'username': 'julia.müller1', 'password_hash': 'c4ca6e6e46d4be6bfe3d183cbea7b3630dc7afb1d08a94483197933374a6676e', 'password_salt': 'cc2ed697', 'user_type': 'REGISTERED', 'registration_date': '2023-07-25', 'old_user': False, 'first_connection': False}
# {'id': 'f5334b02-8985-4389-b2f6-a0806d6cb383', 'first_name': 'Admin', 'last_name': 'User', 'birth_date': '1990-10-08', 'sex': 'Other', 'discord_id': 'admin#6445', 'pseudonym': 'admin8882', 'email': 'admin.user96@example.com', 'username': 'admin.user96', 'password_hash': '3a7beb36b34737ba2fd7416a8b95d363deae50f5a098790385e7c0ed295e2e40', 'password_salt': '50f64989', 'user_type': 'ADMINISTRATOR', 'registration_date': '2023-07-07', 'old_user': False, 'first_connection': False}

# %%
# Insert locations
locations = [
    {"name": "Saint Vincent Center", "address": "123 Rue Saint Vincent, Orléans", "latitude": 47.9029, "longitude": 1.9040},
    {"name": "Orléans Community Center", "address": "456 Avenue de la Communauté, Orléans", "latitude": 47.9129, "longitude": 1.9140}
]
location_insert = """
INSERT INTO locations (name, address, latitude, longitude, description)
VALUES (%s, %s, %s, %s, %s)
"""
location_ids = {}
for loc in locations:
    cursor.execute(location_insert, (
        loc['name'], loc['address'], loc['latitude'], loc['longitude'],
        f"Description for {loc['name']}".replace("'", "''")
    ))
    cursor.execute("SELECT LAST_INSERT_ID()")
    location_ids[loc['name']] = cursor.fetchone()[0]

# %%
# Insert regular schedules
schedule_insert = """
INSERT INTO location_schedule (location_id, start_time, end_time, recurrence_type, recurrence_pattern)
VALUES (%s, %s, %s, %s, %s)
"""
cursor.execute(schedule_insert, (
    location_ids["Saint Vincent Center"], "19:15:00", "01:00:00", "WEEKLY",
    '{"byDay":"FR","interval":1}'
))
cursor.execute(schedule_insert, (
    location_ids["Orléans Community Center"], "14:00:00", "20:00:00", "WEEKLY",
    '{"byDay":"SA","interval":1}'
))

# %%
# Insert association weekend events and schedules
event_insert = """
INSERT INTO events (name, description, start_date, end_date, location_id)
VALUES (%s, %s, %s, %s, %s)
"""
event_ids = []
for month in range(1, 7):
    sunday = get_first_sunday(month)
    friday = sunday - datetime.timedelta(days=2)
    cursor.execute(event_insert, (
        f"Association Weekend {month}", "Monthly gaming event", friday.isoformat(),
        sunday.isoformat(), location_ids["Saint Vincent Center"]
    ))
    cursor.execute("SELECT LAST_INSERT_ID()")
    event_id = cursor.fetchone()[0]
    event_ids.append(event_id)
    
    # Friday schedule
    cursor.execute(schedule_insert, (
        location_ids["Saint Vincent Center"], "19:15:00", "01:00:00", "NONE",
        f'{{"event_id":{event_id}}}'
    ))
    # Saturday schedule
    cursor.execute(schedule_insert, (
        location_ids["Saint Vincent Center"], "10:00:00", "01:00:00", "NONE",
        f'{{"event_id":{event_id}}}'
    ))
    # Sunday schedule
    cursor.execute(schedule_insert, (
        location_ids["Saint Vincent Center"], "10:00:00", "01:00:00", "NONE",
        f'{{"event_id":{event_id}}}'
    ))

# %%
# Insert games
game_insert = """
INSERT INTO games (name, description, type)
VALUES (%s, %s, %s)
"""
game_ids = {}
all_games = board_games + jdr_games
for game in all_games:
    game_type = "BOARD_GAME" if game in board_games else "JDR"
    try:
        cursor.execute(game_insert, (
            game, generate_description(game), game_type
        ))
        cursor.execute("SELECT LAST_INSERT_ID()")
        game_ids[game] = cursor.fetchone()[0]
    
    except	: 
        print('This ' + game +' game is in double')

# Generate parties
parties = []
closed_campaigns = 25
open_campaigns = 8
oneshots = 7  # 7 regular + 8 board game one-shots = 15 total one-shots
board_game_oneshots = 8
total_parties = closed_campaigns + open_campaigns + oneshots + board_game_oneshots

# Closed campaigns
for _ in range(closed_campaigns):
    game = random.choice(all_games)
    max_players = random.randint(4, 7)
    parties.append({
        "type": "CAMPAIGN", "campaign_type": "CLOSED", "game": game,
        "max_players": max_players, "mj_id": random.choice(users)['id']
    })

# Open campaigns
for _ in range(open_campaigns):
    game = random.choice(all_games)
    max_players = random.randint(4, 7)
    parties.append({
        "type": "CAMPAIGN", "campaign_type": "OPEN", "game": game,
        "max_players": max_players, "mj_id": random.choice(users)['id']
    })

# Regular one-shots
for _ in range(oneshots):
    game = random.choice(all_games)
    max_players = random.randint(4, 7)
    parties.append({
        "type": "ONESHOT", "campaign_type": None, "game": game,
        "max_players": max_players, "mj_id": random.choice(users)['id']
    })

# Board game one-shots on Association Weekend Sundays
sunday_dates = [get_first_sunday(month) for month in range(1, 7)]
sunday_dates = sunday_dates[:4] * 2  # 8 dates (2 per month for first 4 months)
for date in sunday_dates:
    game = random.choice(board_games)
    max_players = random.randint(4, 7)
    parties.append({
        "type": "BOARD_GAME", "campaign_type": None, "game": game,
        "max_players": max_players, "mj_id": random.choice(users)['id'],
        "session_date": date
    })
# Out:
# This Fallout game is in double
# This Root game is in double
# This Le domaine des humains game is in double

# %%
# Insert parties
partie_insert = """
INSERT INTO partie (game_id, mj_id, partie_type, campaign_type, short_description, description, max_players)
VALUES (%s, %s, %s, %s, %s, %s, %s)
"""
partie_ids = []
for p in parties:
    game_type = "BOARD_GAME" if p['game'] in board_games else "JDR"
    cursor.execute(partie_insert, (
        game_ids[p['game']], p['mj_id'], p['type'], p['campaign_type'],
        generate_short_description(p['game'], p['type']), generate_description(p['game']),
        p['max_players']
    ))
    cursor.execute("SELECT LAST_INSERT_ID()")
    partie_ids.append(cursor.fetchone()[0])

# %%
# Insert partie_members
partie_members_insert = """
INSERT INTO partie_members (partie_id, user_id)
VALUES (%s, %s)
"""
partie_members = []
for idx, p in enumerate(parties):
    if p['type'] == "CAMPAIGN":
        maxp = p['max_players']
        if p['campaign_type'] == "OPEN":
            count = maxp + random.randint(1, 3)
        else:
            count = random.randint(1, maxp)
        selected_users = random.sample(users, min(count, len(users)))
        for user in selected_users:
            cursor.execute(partie_members_insert, (partie_ids[idx], user['id']))
            partie_members.append((partie_ids[idx], user['id']))

# %%
# Generate sessions (Jan 1, 2025 to Jun 30, 2025)
session_insert = """
INSERT INTO sessions (partie_id, location_id, session_date, start_time, end_time, mj_id)
VALUES (%s, %s, %s, %s, %s, %s)
"""
sessions = []
for idx, p in enumerate(parties):
    if p['type'] == "CAMPAIGN":
        # Random date in first half of 2025
        session_date = datetime.date(2025, random.randint(1, 6), random.randint(1, 28))
        start_time = "19:15:00"
        end_time = "22:15:00"
        mj_id = p['mj_id']
        cursor.execute(session_insert, (
            partie_ids[idx], location_ids["Saint Vincent Center"],
            session_date, start_time, end_time, mj_id
        ))
        cursor.execute("SELECT LAST_INSERT_ID()")
        sessions.append({"id": cursor.fetchone()[0], "partie_id": partie_ids[idx]})
    elif p['type'] == "BOARD_GAME" and 'session_date' in p:
        # Board game one-shots on Sundays
        start_time = "14:00:00"
        end_time = "17:00:00"
        mj_id = p['mj_id']
        cursor.execute(session_insert, (
            partie_ids[idx], location_ids["Saint Vincent Center"],
            p['session_date'], start_time, end_time, mj_id
        ))
        cursor.execute("SELECT LAST_INSERT_ID()")
        sessions.append({"id": cursor.fetchone()[0], "partie_id": partie_ids[idx]})
    elif p['type'] == "ONESHOT":
        # Regular one-shots on Fridays
        session_date = datetime.date(2025, random.randint(1, 6), random.randint(1, 28))
        while session_date.weekday() != 4:  # Friday
            session_date += datetime.timedelta(days=1)
        start_time = "19:15:00"
        end_time = "22:15:00"
        mj_id = p['mj_id']
        cursor.execute(session_insert, (
            partie_ids[idx], location_ids["Saint Vincent Center"],
            session_date, start_time, end_time, mj_id
        ))
        cursor.execute("SELECT LAST_INSERT_ID()")
        sessions.append({"id": cursor.fetchone()[0], "partie_id": partie_ids[idx]})

# %%
# Insert session_players
session_players_insert = """
INSERT INTO session_players (session_id, user_id)
VALUES (%s, %s)
"""
for session in sessions:
    partie_id = session['partie_id']
    partie_idx = partie_ids.index(partie_id)
    p = parties[partie_idx]
    maxp = p['max_players']
    if p['type'] == "CAMPAIGN":
        # Only partie_members can register
        members = [m[1] for m in partie_members if m[0] == partie_id]
        if members:
            selected = random.sample(members, min(len(members), maxp))
            for user_id in selected:
                cursor.execute(session_players_insert, (session['id'], user_id))
    else:
        # Any user can register for one-shots and board games
        selected = random.sample(users, min(len(users), maxp))
        for user in selected:
            cursor.execute(session_players_insert, (session['id'], user['id']))

# %%
# Commit changes and close connection
conn.commit()
cursor.close()
conn.close()
print("Test data generated and inserted into database")
# Out:
# Test data generated and inserted into database

# %%
# Optionally, write SQL file for reference
with open(SQL_FILE_PATH, 'w', encoding='utf-8') as f:
    f.write(f"USE {DB_NAME};\n\n")
    # Users
    f.write("INSERT INTO users (id, first_name, last_name, birth_date, sex, discord_id, pseudonym, email, username, password_hash, password_salt, user_type, registration_date, old_user, first_connection) VALUES\n")
    f.write(",\n".join([f"('{u['id']}', '{u['first_name']}', '{u['last_name']}', '{u['birth_date']}', '{u['sex']}', '{u['discord_id']}', '{u['pseudonym']}', '{u['email']}', '{u['username']}', '{u['password_hash']}', '{u['password_salt']}', '{u['user_type']}', {'NULL' if u['registration_date'] is None else f'\'{u['registration_date']}\''}, {u['old_user']}, {u['first_connection']})" for u in users]) + ";\n\n")
    # Locations
    f.write("INSERT INTO locations (name, address, latitude, longitude, description) VALUES\n")
    f.write(",\n".join([f"('{loc['name']}', '{loc['address']}', {loc['latitude']}, {loc['longitude']}, 'Description for {loc['name']}')" for loc in locations]) + ";\n\n")
    # Games
    f.write("INSERT INTO games (name, description, type) VALUES\n")
    f.write(",\n".join([f"('{game}', '{generate_description(game)}', '{'BOARD_GAME' if game in board_games else 'JDR'}')" for game in all_games]) + ";\n\n")
    # Parties, partie_members, sessions, and session_players would require mapping IDs from DB
    f.write("-- Additional inserts for parties, members, sessions, and session_players are generated directly in the database\n")
print(f"SQL file written to {SQL_FILE_PATH}")
